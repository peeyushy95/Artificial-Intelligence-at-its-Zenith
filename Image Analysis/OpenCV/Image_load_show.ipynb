# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Second Paramenter can be '''
# cv2.IMREAD_GRAYSCALE : 0
# cv2.IMREAD_COLOR : 1
# cv2.IMREAD_UNCHANGED : -1 '''

# %%
image = cv2.imread('demo.jpg')

# %% [markdown]
# We can display using opencv or matplotlib

# %%
cv2.imshow('image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Using matplotlib

# %%
# %matplotlib inline
plt.xticks(())
plt.yticks(())
plt.imshow(image)
