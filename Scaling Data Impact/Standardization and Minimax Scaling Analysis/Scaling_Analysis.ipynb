# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Importing necessary modules

# %%
df = pd.io.parsers.read_csv(
    'https://raw.githubusercontent.com/rasbt/pattern_classification/master/data/wine_data.csv',
     header=None,
     usecols=[0,1,2]
    )

# %% [markdown]
# Reading Data

# %%
df.columns=['label', 'A', 'B']

df.head()
# Out:
#    label      A     B
# 0      1  14.23  1.71
# 1      1  13.20  1.78
# 2      1  13.16  2.36
# 3      1  14.37  1.95
# 4      1  13.24  2.59

# %% [markdown]
# #Standardization
#
# #Standardizing the features so that they are centered around 0 with a standard deviation of 1 is not only important if we are comparing measurements that have different units

# %%
from sklearn import preprocessing

std_scale = preprocessing.StandardScaler().fit(df[['A','B']])
df_std = std_scale.transform(df[['A','B']])

print('After Standardization mean should be 0 and Standard Deviation is 1')
print ('  Mean\t\tStandard Deviation \nA %f\t%f\nB %f\t%f'
       %(df_std[:,0].mean(),df_std[:,0].std(),df_std[:,1].mean(),df_std[:,1].std()))
# Out:
# After Standardization mean should be 0 and Standard Deviation is 1
#   Mean		Standard Deviation
# A -0.000000	1.000000
# B -0.000000	1.000000

# %% [markdown]
# # Plotting Input and Standard Scale Data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df['A'],df['B'],color='green', label='input scale', alpha=.8)
plt.scatter(df_std[:,0],df_std[:,1],color='blue', label='Standard scale', alpha=.4)
plt.title('A and B feature of Dataset')
plt.xlabel('Feature - A')
plt.ylabel('Feature - B')
plt.legend()

# %% [markdown]
# # MinMax Scaling
# MinValue after Scaling => 0
# MaxValue after Scaling => 1

# %%
minMax_scale = preprocessing.MinMaxScaler().fit(df[['A','B']])
df_minMax = minMax_scale.transform(df[['A','B']])

print ('  Min Value\tMax Value\nA %f\t%f\nB %f\t%f'
       %(df_minMax[:,0].min(),df_minMax[:,0].max(),df_minMax[:,1].min(),df_minMax[:,1].max()))
# Out:
#   Min Value	Max Value
# A 0.000000	1.000000
# B 0.000000	1.000000

# %% [markdown]
# # Plotting Input and MinMax Scaled Data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df['A'],df['B'],color='green', label='input scale', alpha=.8)
plt.scatter(df_minMax[:,0],df_minMax[:,1],color='red', label='MinMax scale', alpha=.2)
plt.title('A and B feature of Dataset')
plt.xlabel('Feature - A')
plt.ylabel('Feature - B')
plt.legend()

# %% [markdown]
# # Plotting Input,Standard and MinMax Scale

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df['A'],df['B'],color='green', label='input scale', alpha=.8)
plt.scatter(df_minMax[:,0],df_minMax[:,1],color='blue', label='MinMax scale', alpha=.2)
plt.scatter(df_std[:,0],df_std[:,1],color='blue', label='Standard scale', alpha=.4)
plt.title('A and B feature of Dataset')
plt.xlabel('Feature - A')
plt.ylabel('Feature - B')
plt.legend()
